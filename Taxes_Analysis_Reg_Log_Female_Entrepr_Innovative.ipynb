# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe=pd.read_csv("~/Downloads/datos.csv", sep = ',')

# %%
dataframe.head(5)
# Out:
#         GDP  Tertiary_Education  Cost_buss_proc  Corporate_Tax  Income_Tax  \
# 0  56812.54               46.51             1.2          2.117      10.565
# 1  56812.54               46.51             1.2          2.117      10.565
# 2  56812.54               46.51             1.2          2.117      10.565
# 3  56812.54               46.51             1.2          2.117      10.565
# 4  56812.54               46.51             1.2          2.117      10.565
#
#    UNEDUC  knowent  opport  suskill  sunewcst  discent  IND_UNK  IND_EXTRAC  \
# 0       0        1       1        1         1        0        0           0
# 1       0        0       0        1         0        1        0           0
# 2       1        1       0        1         0        0        0           0
# 3       1        0       0        0         0        0        0           0
# 4       0        0       0        1         0        1        0           0
#
# ...

# %%
dataframe.describe()
# Out:
#                  GDP  Tertiary_Education  Cost_buss_proc  Corporate_Tax  \
# count   14052.000000        14052.000000    14052.000000   14052.000000
# mean    34839.149598           36.232198        5.350811       2.930242
# std     14708.672532           10.096785        5.555915       1.266542
# min     16546.640000           18.790000        0.000000       1.196000
# 25%     22593.270000           27.270000        1.400000       2.078000
# 50%     32452.660000           40.300000        2.400000       2.410000
# 75%     44993.670000           43.130000        7.000000       4.170000
# max    103788.000000           65.600000       20.700000      10.753000
#
#          Income_Tax        UNEDUC       knowent        opport       suskill  \
# count  14052.000000  14052.000000  14052.000000  14052.000000  14052.000000
# mean       6.342368      0.338599      0.628096      0.501281      0.799388
# std        3.485724      0.473250      0.483330      0.500016      0.400473
# ...

# %%
dataframe.columns
# Out:
# Index(['GDP', 'Tertiary_Education', 'Cost_buss_proc', 'Corporate_Tax',
#        'Income_Tax', 'UNEDUC', 'knowent', 'opport', 'suskill', 'sunewcst',
#        'discent', 'IND_UNK', 'IND_EXTRAC', 'IND_TRANS', 'IND_SERV', 'IND_CONS',
#        'gender', 'age', 'age2', 'TEAyy'],
#       dtype='object')

# %%
dataframe['age2']=dataframe['age']*dataframe['age']

# %%
dataframe['GDP2'] = np.log(dataframe['GDP'])

# %%
dataframe.columns
# Out:
# Index(['GDP', 'Tertiary_Education', 'Cost_buss_proc', 'Corporate_Tax',
#        'Income_Tax', 'UNEDUC', 'knowent', 'opport', 'suskill', 'sunewcst',
#        'discent', 'IND_UNK', 'IND_EXTRAC', 'IND_TRANS', 'IND_SERV', 'IND_CONS',
#        'gender', 'age', 'age2', 'TEAyy'],
#       dtype='object')

# %%
cols1 = ['GDP2','Tertiary_Education','Cost_buss_proc','Corporate_Tax','Income_Tax', 'UNEDUC','knowent','opport','suskill', 'discent','IND_UNK','IND_EXTRAC','IND_TRANS','IND_SERV','IND_CONS','age','age2']
X1=dataframe[cols1]
y1=dataframe['sunewcst']

# %%
np.asarray(dataframe)
# Out:
# array([[5.68125400e+04, 4.65100000e+01, 1.20000000e+00, ...,
#         3.24900000e+03, 1.00000000e+00, 1.09475124e+01],
#        [5.68125400e+04, 4.65100000e+01, 1.20000000e+00, ...,
#         4.09600000e+03, 1.00000000e+00, 1.09475124e+01],
#        [5.68125400e+04, 4.65100000e+01, 1.20000000e+00, ...,
#         3.84400000e+03, 1.00000000e+00, 1.09475124e+01],
#        ...,
#        [2.60511400e+04, 2.55000000e+01, 1.90000000e+00, ...,
#         4.41000000e+02, 1.00000000e+00, 1.01678168e+01],
#        [2.60511400e+04, 2.55000000e+01, 1.90000000e+00, ...,
#         9.00000000e+02, 1.00000000e+00, 1.01678168e+01],
#        [2.60511400e+04, 2.55000000e+01, 1.90000000e+00, ...,
#         1.02400000e+03, 1.00000000e+00, 1.01678168e+01]])

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y1,X1,missing='drop')
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.612776
#          Iterations 5
#                           Results: Logit
# ...
# Model:                Logit            Pseudo R-squared: 0.089
# Dependent Variable:   sunewcst         AIC:              17255.4530
# Date:                 2020-12-26 14:13 BIC:              17383.8119
# No. Observations:     14052            Log-Likelihood:   -8610.7
# Df Model:             16               LL-Null:          -9452.8
# Df Residuals:         14035            LLR p-value:      0.0000
# Converged:            1.0000           Scale:            1.0000
# No. Iterations:       5.0000
# -------------------------------------------------------------------
#                     Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -------------------------------------------------------------------
# GDP2                0.4495   0.1030   4.3655 0.0000  0.2477  0.6513
# ...

# %%
cols1 = ['GEMWORK','GEMHHINC', 'UNEDUC','suskill','knowent','ownmge','gender','age','age2','hhsize']
X1=dataframe[cols1]
y1=dataframe['barel_family']

# %%
cols1 = ['GEMWORK','GEMHHINC', 'UNEDUC','suskill','knowent','ownmge','gender','age','age2','hhsize']
X1=dataframe[cols1]
y1=dataframe['barel_friend']

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y1,X1,missing='drop')
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.116610
#          Iterations 8
#                          Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.012
# Dependent Variable: barel_friend     AIC:              4563.8417
# Date:               2019-07-27 10:16 BIC:              4642.6146
# No. Observations:   19483            Log-Likelihood:   -2271.9
# Df Model:           9                LL-Null:          -2299.4
# Df Residuals:       19473            LLR p-value:      1.2781e-08
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     8.0000
# ------------------------------------------------------------------
#               Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# ------------------------------------------------------------------
# GEMWORK      -0.2288    0.1026   -2.2291  0.0258  -0.4300  -0.0276
# GEMHHINC      0.6800    0.0940    7.2362  0.0000   0.4958   0.8642
# ...
